# %%
import matplotlib.pyplot as plt

# %%
# fig 2 a
datasets = {
    "Greedy": {
        "max_value": 10.01,
        "values": [0.034, 0.067, 0.097, 0.127, 0.156, 0.185, 0.212, 0.239, 0.266, 0.292]
    },
    "DINO": {
        "max_value": 10.01,
        "values": [0.034, 0.064, 0.097, 0.125, 0.154, 0.181, 0.210, 0.236, 0.261, 0.291]
    }
}

# Compute percentages
# Plot settings
plt.figure(figsize=(30, 30))
plt.rcParams['font.family'] = "Times New Roman"
plt.rcParams['font.size'] = 120
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey')
plt.gca().set_facecolor("#eeeeee")

# Plot data
x_values = list(range(1,11))
markers = ['o', 'D', '^', '^', '^']
for (name, data), marker in zip(datasets.items(), markers):
    plt.plot(x_values, data["values"], label=name, marker=marker, markersize=45, linewidth=2)
plt.ylim(0,0.42)
# Labels, legend and save
plt.xlabel('Node Budget')
plt.ylabel('Spectral Radius Decrease')
plt.legend()
plt.tight_layout()
plt.savefig("budget_sensi_analysis.pdf")
plt.show()

# %%
# fig 2 b
# Data
node_numbers = [300, 500, 800, 1200, 1800]
new_scc = [0.47, 0.38, 0.324, 0.25, 0.216]
bruteforce = [0.52, 0.39, 0.329, 0.254, 0.22]

# Setting the style
plt.figure(figsize=(30,30))
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 120
# plt.rcParams['axes.facecolor'] = '#eeeeee'

# Plotting with new names and colors
# plt.plot(node_numbers, scc, label='SCC-deg', marker='^', color='royalblue', markersize=15)
plt.plot(node_numbers, bruteforce, label='Greedy', marker='o', markersize=45)
plt.plot(node_numbers, new_scc, label='DINO', marker='D', markersize=45)


# Adding title, labels, grid and legend
# plt.title('Spect vs Node Number')
plt.xlabel('Node Number')
plt.ylabel('Spectral Radius Decrease')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey') # To remove the background of the legend
plt.gca().set_facecolor("#eeeeee")
plt.tight_layout()
plt.savefig("number_nodes_with_spectrum_drop.pdf")
plt.show()

# %%
# fig 2 a
datasets = {
    "Greedy": {
        "max_value": 10.01,
        "values": [0.034, 0.067, 0.097, 0.127, 0.156, 0.185, 0.212, 0.239, 0.266, 0.292]
    },
    "DINO": {
        "max_value": 10.01,
        "values": [0.034, 0.064, 0.097, 0.125, 0.154, 0.181, 0.210, 0.236, 0.261, 0.291]
    }
}

# Compute percentages
# Plot settings
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
plt.rcParams['font.family'] = "Times New Roman"
plt.rcParams['font.size'] = 30

colors=["#d53e4f","#7985A5"]

# Plot data
x_values = list(range(1,11))
markers = ['o', 'D',]
ax1.plot(x_values, datasets['Greedy']['values'], label='Greedy', marker='o', color=colors[1],markersize=15,markeredgecolor="black", markeredgewidth=1)
ax1.plot(x_values, datasets['DINO']['values'], label='DINO', marker='D', color=colors[0], markersize=15,markeredgecolor="black", markeredgewidth=3)
ax1.set_ylim(0,0.42)
ax1.set_xlabel('Node Budget')
ax1.set_ylabel('Spectral Radius Decrease')
ax1.set_title('Approx. w. Various Node Budgets')
ax1.legend()
ax1.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey')
ax1.set_facecolor("#eeeeee")

node_numbers = [300, 500, 800, 1200, 1800]
new_scc = [0.47, 0.38, 0.324, 0.25, 0.216]
bruteforce = [0.52, 0.39, 0.329, 0.254, 0.22]

# Plotting with new names and colors
ax2.plot(node_numbers, bruteforce, label='Greedy', marker='o', color=colors[1],markersize=15,markeredgecolor="black", markeredgewidth=1)
ax2.plot(node_numbers, new_scc, label='DINO', marker='D', color=colors[0], markersize=15,markeredgecolor="black", markeredgewidth=3)
ax2.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey')
ax2.set_facecolor("#eeeeee")

# Adding title, labels, grid and legend
ax2.set_title('Approx. w. Various Node Numbers')
ax2.set_xlabel('Number of Nodes in Network')
ax2.legend()

ax1.text(0.5, -0.13, '(a)', ha='center', va='top', transform=ax1.transAxes, fontsize=30)
ax2.text(0.5, -0.13, '(b)', ha='center', va='top', transform=ax2.transAxes, fontsize=30)
plt.savefig("fig2.pdf",bbox_inches="tight")
plt.show()

# %%
# fig 3

# %%
plt.figure(figsize=(9.5, 9))
# colors = ["#9e0142", "#d53e4f", "#f46d43", "#fdae61", "#fee08b", "#e6f598", "#abdda4", "#66c2a5", "#3288bd", "#5e4fa2",
#           "#0C3E95","#4CBAE1","#59D9B6","#FDBFAA","#F39CAD","#DC7FAC","#FFD9E9","#F8AFF6","#D88BE7","#AB80DF","#8672D3","#5C69C9",
#           "#FF983B",  "#FE4E4E", "#3466A5", "#634490", "#00C4D4", "#003C4D", "#7763D3", "#028A46", "#B95461", "#7985A5"]
colors = ["#CB9AF3","#7763D3", "#0C3E95", "#3288bd", "#abdda4", "#028A46","#FF983B", "#F8AFF6", "#d53e4f","#7985A5"]
for i in range(len(colors)):
    plt.scatter(i*2,i*2, marker="o", s=800, color=colors[i],edgecolors='black')
plt.show()

# %%
# fig 4 a
labels = ["Ran.", "Deg.", "Katz.", "Clo.", "HITS", "P.R.","Acqu.",
          "CBF.",  "DINO", "Gre."]
# spectral_radius_drop = [0.0013, 1.35, 1.353, 1.362, 0.0665,1.2618,0.0037, 1.129,
#                           1.5079, 1.7162]
# running_time = [0.0003, 0.002, 0.11, 10.27, 0.0027, 1.191, 0.0022, 0.279,  1.8073, 9459]
spectral_radius_drop = [0.007, 0.53, 0.44, 0.416, 0.017, 0.334, 0.0001, 0.5502, 0.755, 0.890]
running_time = [0.0036, 0.0027, 0.258, 63.13, 1.2215, 0.0107, 0.0028, 0.3321, 2.5907, 60379]
# spectral_radius_drop = [34.91, 37.60, 5.8091, 12.09, 0.0006,  30.94, 0.5145, ]
# running_time = [7556.60, 158.9514, 0.2944, 2.0995, 0.006, 0.054,  0.0796, 168.9763]
markers = ['o', 's', 'H', '^', 'v', '<', '>', 'p',  'D', '*',]
# colors = ['b', 'orange', 'r', 'c', 'm', 'y', 'k', 'lime', 'g', 'purple']
# colors = ["#9e0142", "#d53e4f", "#f46d43", "#fdae61", "#fee08b", "#e6f598", "#abdda4", "#66c2a5", "#3288bd", "#5e4fa2"]
# colors = ["#0C3E95","#4CBAE1","#59D9B6","#FDBFAA","#F39CAD","#DC7FAC","#FFD9E9","#F8AFF6","#D88BE7","#AB80DF","#8672D3","#5C69C9"]
# colors = ["#FF983B",  "#FE4E4E", "#3466A5", "#634490", "#00C4D4", "#003C4D", "#7763D3", "#028A46", "#B95461", "#7985A5"]
colors = ["#CB9AF3","#7763D3", "#0C3E95", "#3288bd", "#abdda4", "#028A46","#FF983B", "#F8AFF6", "#d53e4f","#7985A5"]
# Setting the global font parameters again
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 35

# Redrawing the plot with adjusted borderpad for the legend
plt.figure(figsize=(9.5, 9))
plt.xlim(-2500,63000)
for i, label in enumerate(labels):
    if label == "DINO":
        plt.scatter(running_time[i], spectral_radius_drop[i], marker=markers[i], s=800, color=colors[i], label=label,edgecolors='black', linewidths=3)
    else:
        plt.scatter(running_time[i], spectral_radius_drop[i], marker=markers[i], s=800, color=colors[i], label=label,edgecolors='black')
plt.plot([running_time[labels.index("DINO")], running_time[labels.index("Gre.")]],[spectral_radius_drop[labels.index("DINO")], spectral_radius_drop[labels.index("Gre.")]], '--', color="black")
# plt.plot([[running_time[labels.index("DINO")], running_time[labels.index("Gre.")]],spectral_radius_drop[labels.index("DINO")], spectral_radius_drop[labels.index("Gre.")]], 'ro-')
plt.legend(loc='lower right', markerscale=1, fontsize=40, ncol=2, columnspacing=0.,
            handletextpad=0.2, frameon=True, borderpad=0.1)  # Adjusted borderpad parameter
plt.ylabel("Spectral Radius Decrease")
plt.xlabel("Running Time (s)")
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey') # To remove the background of the legend
plt.gca().set_facecolor("#eeeeee")
plt.tight_layout()
plt.savefig("scale_plot.pdf")
plt.show()

# %%
# fig 4 b 
plt.figure(figsize=(9.5,9))
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 35
x_vals = [264, 678, 1996, 4242, 9213, 16429, 24643, 31764, 38000, 50491, 60498, 70630, 81395, 92465, 101544]
y_vals = [0.08232426643371582, 0.10591363906860352, 0.1337752342224121, 0.3432091474533081, 0.745266318321228, 1.195417046546936, 1.7065284252166748, 2.408107042312622, 3.1415103673934937, 4.015967965126038, 5.067585587501526, 6.067762732505798, 7.336578369140625, 8.789085745811462, 9.759629845619202]
y_errors = [0.04958295822143555, 0.0009667873382568359, 0.009415864944458008, 0.09038817882537842, 0.14035570621490479, 0.0012153387069702148, 0.026038408279418945, 0.009243249893188477, 0.01626718044281006, 0.009295821189880371, 0.000841975212097168, 0.03262174129486084, 0.00015592575073242188, 0.05888330936431885, 0.060507893562316895]
upper_bound = [0.13190722465515137, 0.10688042640686035, 0.14319109916687012, 0.4335973262786865, 0.8856220245361328, 1.1966323852539062, 1.7325668334960938, 2.4173502922058105, 3.1577775478363037, 4.025263786315918, 5.068427562713623, 6.100384473800659, 7.336734294891357, 8.847969055175781, 9.820137739181519]
lower_bound= [0.03274130821228027, 0.10494685173034668, 0.1243593692779541, 0.2528209686279297, 0.6049106121063232, 1.1942017078399658, 1.6804900169372559, 2.3988637924194336, 3.1252431869506836, 4.006672143936157, 5.066743612289429, 6.0351409912109375, 7.336422443389893, 8.730202436447144, 9.699121952056885]
marker = "D"
plt.plot(x_vals, y_vals, marker=marker,label="DINO", color="#367E21", markersize=15)
# Adding the shaded region here
plt.fill_between(x_vals, lower_bound, upper_bound, color="#367E21", alpha=0.3)
plt.xlabel("|V|+|E|")
plt.ylabel("Running Time")
plt.legend(loc="upper left")
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey') # To remove the background of the legend
plt.gca().set_facecolor("#eeeeee")
plt.tight_layout()
plt.savefig("scalability.pdf")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(19,9))
plt.rcParams['font.family'] = "Times New Roman"
plt.rcParams['font.size'] = 30

labels = ["Ran.", "Deg.", "Katz.", "Clo.", "HITS", "P.R.","Acqu.",
          "CBF.",  "DINO", "Gre."]
spectral_radius_drop = [0.007, 0.53, 0.44, 0.416, 0.017, 0.334, 0.0001, 0.5502, 0.755, 0.890]
running_time = [0.0036, 0.0027, 0.258, 63.13, 1.2215, 0.0107, 0.0028, 0.3321, 2.5907, 60379]

markers = ['o', 's', 'H', '^', 'v', '<', '>', 'p',  'D', '*',]
colors = ["#CB9AF3","#7763D3", "#0C3E95", "#3288bd", "#abdda4", "#028A46","#FF983B", "#F8AFF6", "#d53e4f","#7985A5"]
ax1.set_xlim(-2500,63000)
for i, label in enumerate(labels):
    if label == "DINO":
        ax1.scatter(running_time[i], spectral_radius_drop[i], marker=markers[i], s=800, color=colors[i], label=label,edgecolors='black', linewidths=3)
    else:
        ax1.scatter(running_time[i], spectral_radius_drop[i], marker=markers[i], s=800, color=colors[i], label=label,edgecolors='black')
ax1.plot([running_time[labels.index("DINO")], running_time[labels.index("Gre.")]],[spectral_radius_drop[labels.index("DINO")], spectral_radius_drop[labels.index("Gre.")]], '--', color="black")
ax1.legend(loc='lower right', markerscale=1, fontsize=40, ncol=2, columnspacing=0.,
            handletextpad=0.2, frameon=True, borderpad=0.1)  # Adjusted borderpad parameter
ax1.set_ylabel("Spectral Radius Decrease")
ax1.set_xlabel("Running Time (s)")
ax1.set_title('Quality Time Trade-off')
ax1.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey')
ax1.set_facecolor("#eeeeee")

x_vals = [264, 678, 1996, 4242, 9213, 16429, 24643, 31764, 38000, 50491, 60498, 70630, 81395, 92465, 101544]
y_vals = [0.08232426643371582, 0.10591363906860352, 0.1337752342224121, 0.3432091474533081, 0.745266318321228, 1.195417046546936, 1.7065284252166748, 2.408107042312622, 3.1415103673934937, 4.015967965126038, 5.067585587501526, 6.067762732505798, 7.336578369140625, 8.789085745811462, 9.759629845619202]
y_errors = [0.04958295822143555, 0.0009667873382568359, 0.009415864944458008, 0.09038817882537842, 0.14035570621490479, 0.0012153387069702148, 0.026038408279418945, 0.009243249893188477, 0.01626718044281006, 0.009295821189880371, 0.000841975212097168, 0.03262174129486084, 0.00015592575073242188, 0.05888330936431885, 0.060507893562316895]
upper_bound = [0.13190722465515137, 0.10688042640686035, 0.14319109916687012, 0.4335973262786865, 0.8856220245361328, 1.1966323852539062, 1.7325668334960938, 2.4173502922058105, 3.1577775478363037, 4.025263786315918, 5.068427562713623, 6.100384473800659, 7.336734294891357, 8.847969055175781, 9.820137739181519]
lower_bound= [0.03274130821228027, 0.10494685173034668, 0.1243593692779541, 0.2528209686279297, 0.6049106121063232, 1.1942017078399658, 1.6804900169372559, 2.3988637924194336, 3.1252431869506836, 4.006672143936157, 5.066743612289429, 6.0351409912109375, 7.336422443389893, 8.730202436447144, 9.699121952056885]
marker = "D"
ax2.plot(x_vals, y_vals, marker=marker,label="DINO", color="#d53e4f", markersize=15)
# Adding the shaded region here
ax2.fill_between(x_vals, lower_bound, upper_bound, color="#d53e4f", alpha=0.3)
ax2.set_xlabel("|V|+|E|")
ax2.set_ylabel("Running Time")
ax2.legend(loc="upper left")
ax2.grid(True, which='both', linestyle='--', linewidth=0.5, color='grey') # To remove the background of the legend
ax2.set_title("Scalability Analysis")
ax2.set_facecolor("#eeeeee")

ax1.text(0.5, -0.18, '(a) in p2p-Gnutella', ha='center', va='top', transform=ax1.transAxes, fontsize=30)
ax2.text(0.5, -0.18, '(b) in Erdős–Rényi', ha='center', va='top', transform=ax2.transAxes, fontsize=30)
plt.savefig("fig4.pdf",bbox_inches="tight")
plt.show()

# %%
# SIS
sis= [{'method': 'Random', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 100], 'i': [82, 70, 67, 133, 114, 132, 184, 128, 135, 145, 110, 155, 137, 167, 120, 154, 168, 108, 120, 128, 169, 134, 134, 152, 170, 150, 153, 142, 150, 154, 128, 165, 181, 172, 172]}, {'method': 'DegreeDirect', 't': [1, 4, 7, 10, 13, 13], 'i': [64, 16, 16, 5, 0, 0]}, {'method': 'KatzCentrality', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 32], 'i': [59, 76, 73, 38, 88, 41, 67, 45, 51, 32, 5, 0]}, {'method': 'ClosenessCentrality', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 100], 'i': [53, 33, 68, 92, 131, 98, 73, 64, 65, 92, 79, 50, 50, 53, 72, 84, 86, 48, 78, 133, 102, 87, 106, 105, 63, 75, 90, 39, 41, 56, 84, 106, 123, 66, 66]}, {'method': 'Hits', 't': [1, 4, 7, 10, 13, 16, 19, 22, 23], 'i': [69, 30, 38, 30, 31, 20, 4, 2, 0]}, {'method': 'PageRank', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 100], 'i': [72, 104, 107, 107, 81, 94, 78, 110, 97, 140, 98, 104, 123, 84, 57, 71, 90, 62, 145, 137, 144, 93, 118, 99, 102, 128, 142, 116, 118, 139, 79, 105, 59, 52, 52]}, {'method': 'Acquaintance', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 100], 'i': [62, 50, 32, 28, 33, 97, 131, 91, 117, 101, 131, 119, 156, 98, 136, 139, 158, 171, 136, 174, 152, 123, 150, 125, 168, 158, 142, 185, 166, 121, 115, 149, 134, 162, 162]}, {'method': 'CBF', 't': [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 100], 'i': [70, 75, 143, 144, 126, 123, 115, 170, 124, 124, 162, 176, 209, 175, 126, 137, 128, 114, 127, 104, 105, 97, 145, 140, 155, 131, 141, 131, 93, 125, 87, 107, 128, 155, 155]}, {'method': 'DINO', 't': [1, 4, 7, 10, 13, 15], 'i': [56, 35, 46, 43, 4, 0]}]
# SIR
sir=[{'method': 'Random', 't': [7.240114950354129, 7.3673352615589165, 7.796917239463557, 8.331782082217474, 9.189605429928607, 10.239547728021645, 12.593352000210055, 13.802974690994793], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'DegreeDirect', 't': [7.479588262089966, 7.617717443765023, 7.825944068670837, 7.89698707589282, 8.24571869730777, 8.441430414246874, 8.883667179570818, 9.822422631527187], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'KatzCentrality', 't': [7.402944527234356, 7.496612954015094, 7.884086988722916, 8.10825619488407, 8.573318113509444, 9.28253615855687, 10.408089975993967, 12.037161119775595], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'ClosenessCentrality', 't': [7.305698796790826, 7.4982690556715665, 7.874581447599285, 8.608672922473506, 9.255110373739553, 10.116888607541004, 10.594458182379448, 16.81354732711379], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'Hits', 't': [7.209764259477549, 7.407732258815947, 7.70298487701556, 8.122414866836102, 8.30561909192888, 8.68474423534194, 11.13604458769855, 11.277461710624209], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'PageRank', 't': [7.631231628149512, 8.011210672388346, 8.182294666714974, 8.204164442888397, 8.650246280526009, 9.22505927074785, 10.56298871782679, 12.274949176110301], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'Acquaintance', 't': [7.587464896309652, 7.741507975565016, 7.979780541960993, 8.492561210281469, 8.744361173469455, 9.326620589073206, 9.795789364146312, 9.813042971292788], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'CBF', 't': [7.614286069494859, 7.92774626803704, 7.989682403752586, 8.145585142625501, 8.617347689325355, 8.939744665234997, 9.740286242220646, 10.826896489957377], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'DINO', 't': [7.472006514606256, 7.664492285482175, 7.8608118800293525, 8.090472069557242, 8.291532905137348, 8.663193903641114, 9.175821296471458, 10.83771408491056], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}]
seir = [{'method': 'Random', 't': [7.5445543482061295, 7.68904291873315, 7.904529131677418, 8.497613312164079, 8.78905383381489, 8.921345524265746, 10.23254010116074, 10.323858880819605], 'i': [17, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'DegreeDirect', 't': [7.14502048171106, 7.461761802331024, 7.720168425332854, 7.839374611538113, 8.085271635425325, 8.698777908639014, 9.415706541899368, 9.65074715700649], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'KatzCentrality', 't': [7.112286964169713, 7.253361526365131, 7.504666483216536, 7.749751123071723, 7.891241724622425, 8.885193312059933, 10.808662349449106, 11.448604390577822], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'ClosenessCentrality', 't': [7.551733212356015, 7.665875669300271, 7.824993893844974, 8.583764078671633, 8.836028663910136, 10.113814940446684, 10.937868417406944, 11.528183624494599], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'Hits', 't': [7.382415585900035, 7.723848124149584, 7.9078703263959955, 8.456987386581922, 9.180538137293617, 11.94414482584688, 12.203512612125177, 13.08306980558578], 'i': [17, 14, 13, 10, 7, 4, 1, 0]}, {'method': 'PageRank', 't': [7.067948417991568, 7.179589856509142, 7.294988547070445, 7.829988655822731, 7.971762746110014, 8.414672163928174, 11.350919298382324, 12.195536167809495], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'Acquaintance', 't': [7.953526486315721, 8.199896130833864, 8.308649740506219, 8.708265705928419, 9.189934325986892, 9.540298758174464, 10.210629026475543, 15.255627306217995], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'CBF', 't': [7.856404452585186, 8.199845074572357, 8.66086089138975, 8.685957119314464, 8.955336527164079, 10.150106294225024, 11.232616885834679, 11.39265873001997], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}, {'method': 'DINO', 't': [7.326773082012575, 7.569034926358491, 7.855150439141536, 8.256777900436223, 8.409057772035487, 9.105626022308764, 9.61721810465361, 9.721829648910855], 'i': [19, 16, 13, 10, 7, 4, 1, 0]}]

# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25, 8))
ax_list = [ax1, ax2, ax3]
model = [sis, sir, seir]
methods = ['Random', 'DegreeDirect', 'KatzCentrality', 'ClosenessCentrality', 'Hits', 'PageRank', 'Acquaintance', 'CBF', 'DINO']
labels = ['Random', 'Degree', 'Katz.', 'Close.', 'HITS', 'PageRank', 'Acqu.', 'CBF', 'DINO']
colors = ["#CB9AF3","#7763D3", "#0C3E95", "#3288bd", "#abdda4", "#028A46","#FF983B", "#F8AFF6", "#d53e4f"]
markers = ['o', 's', 'H', '^', 'v', '<', '>', 'p',  'D']

for a in range(3):
    for i in range(len(labels)):
        if labels[i] == "DINO":
            ax_list[a].plot(model[a][i]['t'], model[a][i]['i'], label=labels[i], marker=markers[i], markersize=10, color=colors[i],markeredgecolor="black", markeredgewidth=2)
        else:
            ax_list[a].plot(model[a][i]['t'], model[a][i]['i'], label=labels[i], marker=markers[i], markersize=10, color=colors[i])
        ax_list[a].set_xlabel("Time", fontname='Times New Roman', fontsize=25)
        ax_list[a].set_facecolor("#eeeeee")
        ax_list[a].grid(True, which='both', linestyle='--', linewidth=0.5, color="grey")
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']
rcParams['font.size'] = 25

plt.tight_layout()
legend = ax2.legend(loc='upper center', bbox_to_anchor=(0.5,1.2),
          fancybox=False, shadow=False,frameon=False, ncol=5) 
for handle in legend.legendHandles:
    handle.set_markersize(20)
ax1.text(0.5, -0.13, '(a) SIS ($I_0$ = 0.95, $\\beta$=0.03)', ha='center', va='top', transform=ax1.transAxes, fontsize=25)
ax2.text(0.5, -0.13, '(b) SIR ($I_0$ = 0.95, $\\beta$=0.03, $\\alpha_{IR}$ = 0.8)', ha='center', va='top', transform=ax2.transAxes, fontsize=25)
ax3.text(0.5, -0.13, '(c) SEIR ($I_0$ = 0.95, $\\beta_1$=0.00,$\\beta_2$=0.03, \n $\\alpha_{EI}$ = 0.1, $\\alpha_{IR}$ = 0.8)', ha='center', va='top', transform=ax3.transAxes, fontsize=25)
ax1.set_ylabel("Infected people", fontname='Times New Roman', fontsize=25)
plt.savefig("fig3.pdf",bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_1199926/1325721047.py:28: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend.legendHandles:
